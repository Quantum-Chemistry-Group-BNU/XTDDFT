# %%
from pyscf import gto, dft, scf, ao2mo, lib, tddft,fci
from pyscf.fci import addons
import numpy as np
from pyscf.dft import numint
import scipy
from functools import reduce
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
import re
from pyscf import tools
from SF_XTDA import *
# Out:
# /Users/zhendongli/.local/lib/python3.9/site-packages/pyscf/dft/libxc.py:771: UserWarning: Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, corresponding to the original definition by Stephens et al. (issue 1480) and the same as the B3LYP functional in Gaussian. To restore the VWN5 definition, you can put the setting "B3LYP_WITH_VWN5 = True" in pyscf_conf.py
#   warnings.warn('Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, '

# %%
mol = gto.M(                 
    atom = f'''
    Be 0 0 0''',
    basis = '6-31g**',
    charge = 0,
    spin = 2, 
    verbose = 5,
    #cart=True,
    symmetry=True, #'D2h'
)


mf = dft.ROKS(mol)
#mf.irrep_nelec = {'A1': (4,2), 'B1':(1,1), 'B2':(1,1)}
mf.xc = 'bhandhlyp'
mf.kernel()
# Out:
# System: uname_result(system='Darwin', node='Zhendongs-Macbook-Pro.local', release='23.1.0', version='Darwin Kernel Version 23.1.0: Mon Oct  9 21:32:11 PDT 2023; root:xnu-10002.41.9~7/RELEASE_ARM64_T6030', machine='arm64')  Threads 1
# Python 3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:01:00)
# [Clang 13.0.1 ]
# numpy 1.24.2  scipy 1.9.3
# Date: Fri Sep  5 17:45:08 2025
# PySCF version 2.4.0
# PySCF path  /Users/zhendongli/.local/lib/python3.9/site-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 5
# [INPUT] max_memory = 4000
# [INPUT] num. atoms = 1
# [INPUT] num. electrons = 4
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 2
# [INPUT] symmetry True subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 Be     0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# [INPUT] ---------------- BASIS SET ----------------
# [INPUT] l, kappa, [nprim/nctr], expnt,             c_1 c_2 ...
# [INPUT] Be
# [INPUT] 0    0    [6    /1   ]  1264.5857         0.0019448
#                                 189.93681         0.0148351
#                                 43.159089         0.0720906
#                                 12.098663         0.2371542
#                                 3.8063232         0.4691987
#                                 1.2728903         0.3565202
# [INPUT] 0    0    [3    /1   ]  3.1964631         -0.1126487
#                                 0.7478133         -0.2295064
#                                 0.2199663         1.1869167
# [INPUT] 0    0    [1    /1   ]  0.0823099            1
# [INPUT] 1    0    [3    /1   ]  3.1964631         0.0559802
#                                 0.7478133         0.2615506
#                                 0.2199663         0.7939723
# [INPUT] 1    0    [1    /1   ]  0.0823099            1
# [INPUT] 2    0    [1    /1   ]  0.4                  1
#
# nuclear repulsion = 0
# point group symmetry = SO3
# symmetry origin: [0. 0. 0.]
# symmetry axis x: [1. 0. 0.]
# symmetry axis y: [0. 1. 0.]
# symmetry axis z: [0. 0. 1.]
# num. orbitals of irrep s+0 = 3
# num. orbitals of irrep p-1 = 2
# num. orbitals of irrep p+0 = 2
# num. orbitals of irrep p+1 = 2
# num. orbitals of irrep d-2 = 1
# num. orbitals of irrep d-1 = 1
# num. orbitals of irrep d+0 = 1
# num. orbitals of irrep d+1 = 1
# num. orbitals of irrep d+2 = 1
# number of shells = 6
# number of NR pGTOs = 27
# number of NR cGTOs = 14
# basis = 6-31g**
# ecp = {}
# CPU time:         0.67
#
#
# ******** <class 'pyscf.dft.rks_symm.SymAdaptedROKS'> ********
# method = SymAdaptedROKS
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /var/folders/qd/v2qd0s4n4w3flpf2dgfyvqzh0000gn/T/tmpq7_95sfv
# max_memory 4000 MB (current use 0 MB)
# num. doubly occ = 1  num. singly occ = 2
# XC library pyscf.dft.libxc version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
# XC functionals = bhandhlyp
#     A. D. Becke.,  J. Chem. Phys. 98, 1372 (1993)
#     Defined through Gaussian implementation.
# radial grids:
#     Treutler-Ahlrichs [JCP 102, 346 (1995); DOI:10.1063/1.469408] (M4) radial grids
#
# becke partition: Becke, JCP 88, 2547 (1988); DOI:10.1063/1.454033
# pruning grids: <function nwchem_prune at 0x120365f70>
# grids dens level: 3
# symmetrized grids: True
# atomic radii adjust function: <function treutler_atomic_radii_adjust at 0x120365ee0>
# small_rho_cutoff = 1e-07
# Freeze 0 electrons in irreps []
#     4 free electrons in irreps s+0 p-1 p+0 p+1 d-2 d-1 d+0 d+1 d+2
# Set gradient conv threshold to 3.16228e-05
# atom Be rad-grids = 75, ang-grids = [ 50  50  50  50  50  50  50  50  50  50  50  50  50  50  50  50  50  50
#   50  50  50  50  50  50  50  50  86  86  86  86  86  86  86  86  86  86
#   86 266 266 266 266 266 266 266 266 302 302 302 302 302 302 302 302 302
#  302 302 302 302 302 302 302 302 302 302 302 302 266 266 266 266 266 266
#  266 266 266]
# tot_boxes 729, boxes in each direction [7 7 7]
# Padding 2 grids
# tot grids = 13112
#     CPU time for setting up grids      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [1.99873003 1.99873003]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -19.134240911590176  Ecoul = 7.255001638216241  Exc = -2.7786583012785675
# init E= -14.6578975746525
# cond(S) = 15.204045198862124
#     CPU time for initialize scf      0.04 sec, wall time      0.04 sec
# HOMO (p+0) = 0.00596259350388889  LUMO (p-1) = 0.00596259350388896
# double occ irrep_nelec = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# single occ irrep_nelec = [1, 0, 1, 0, 0, 0, 0, 0, 0]
#                   Roothaan           | alpha              | beta
#   Highest 2-occ =  -4.31547382665886 |  -4.31547382665886 |  -4.31547382665886
#   Lowest 0-occ =  0.00596259350388896 | 0.00596259350388894 | 0.00596259350388894
#   1-occ =         -0.258025038559303 | -0.258025038559303 | -0.258025038559303
#   1-occ =         0.00596259350388889 | 0.00596259350388888 | 0.00596259350388888
#   Roothaan mo_energy =
# [-4.31547383 -0.25802504  0.35630473  0.00596259  0.34561469  0.00596259
#   0.34561469  0.00596259  0.34561469  0.93426832  0.93426832  0.93426832
#   0.93426832  0.93426832]
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -18.789138892242526  Ecoul = 6.995184844134305  Exc = -2.7645980590579766
# cycle= 1 E= -14.5585521071662  delta_E= 0.0993  |g|= 0.0561  |ddm|= 0.942
#     CPU time for cycle= 1      0.01 sec, wall time      0.01 sec
# HOMO (p+0) = -0.0688262003266134  LUMO (p+1) = -0.0075098940906729
# double occ irrep_nelec = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# single occ irrep_nelec = [1, 0, 1, 0, 0, 0, 0, 0, 0]
#                   Roothaan           | alpha              | beta
#   Highest 2-occ =   -4.4068728796871 |  -4.41794601486415 |  -4.39579668819967
#   Lowest 0-occ =  -0.0075098940906729 | -0.0321295146295604 | 0.0171097264482127
#   1-occ =         -0.215225219070559 | -0.327478589051648 | -0.100922120755861
#   1-occ =         -0.0688262003266134 | -0.177040976459726 | 0.0511938070680402
#   Roothaan mo_energy =
# [-4.40687288 -0.21522522  0.34204515 -0.00750989  0.31227556 -0.0688262
#   0.32068232 -0.00750989  0.31227556  0.89106868  0.89817408  0.90132819
#   0.89817408  0.89106872]
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -18.950040051851513  Ecoul = 7.187227774825952  Exc = -2.8037375404247094
# cycle= 2 E= -14.5665498174503  delta_E= -0.008  |g|= 0.00725  |ddm|= 0.288
#     CPU time for cycle= 2      0.01 sec, wall time      0.01 sec
# HOMO (p+0) = -0.0442576216420822  LUMO (p+1) = 0.0132418538685858
# double occ irrep_nelec = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# single occ irrep_nelec = [1, 0, 1, 0, 0, 0, 0, 0, 0]
#                   Roothaan           | alpha              | beta
#   Highest 2-occ =  -4.34042354992682 |  -4.35216144031301 |  -4.32645603810821
#   Lowest 0-occ =  0.0132418538685858 | -0.0111839400839873 | 0.0383454196506802
#   1-occ =         -0.189993047022108 | -0.307100724611304 |  -0.07262851724371
#   1-occ =         -0.0442576216420822 | -0.166171209471233 | 0.0789487230964392
#   Roothaan mo_energy =
# [-4.34042355 -0.18999305  0.35933591  0.01324185  0.33770136 -0.04425762
#   0.33528049  0.01324185  0.33770136  0.9215764   0.92916289  0.93246763
#   0.92916289  0.92157662]
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -18.94702777708087  Ecoul = 7.182923223393479  Exc = -2.8024979238433168
# cycle= 3 E= -14.5666024775307  delta_E= -5.27e-05  |g|= 0.000604  |ddm|= 0.0284
#     CPU time for cycle= 3      0.01 sec, wall time      0.01 sec
# HOMO (p+0) = -0.0440437912910304  LUMO (p+1) = 0.0132414755504746
# double occ irrep_nelec = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# single occ irrep_nelec = [1, 0, 1, 0, 0, 0, 0, 0, 0]
#                   Roothaan           | alpha              | beta
#   Highest 2-occ =  -4.34055259067495 |  -4.35362049779088 |  -4.32792187854674
#   Lowest 0-occ =  0.0132414755504746 | -0.0115296511798374 | 0.0378742747508073
#   1-occ =         -0.190030902306416 | -0.306997847174506 | -0.0732884308964661
#   1-occ =         -0.0440437912910304 | -0.166841585480767 |  0.078683253656597
#   Roothaan mo_energy =
# [-4.34055259 -0.1900309   0.35990093  0.01324148  0.33779071 -0.04404379
#   0.33484001  0.01324148  0.33779071  0.92159468  0.92922741  0.93252594
#   0.92922741  0.92159494]
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -18.947493533199925  Ecoul = 7.183490034530887  Exc = -2.802599819805018
# cycle= 4 E= -14.5666033184741  delta_E= -8.41e-07  |g|= 2.07e-05  |ddm|= 0.00349
#     CPU time for cycle= 4      0.01 sec, wall time      0.01 sec
# HOMO (p+0) = -0.044037486593998  LUMO (p+1) = 0.0132263897563843
# double occ irrep_nelec = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# single occ irrep_nelec = [1, 0, 1, 0, 0, 0, 0, 0, 0]
#                   Roothaan           | alpha              | beta
#   Highest 2-occ =  -4.34057347376814 |  -4.35341997785982 |  -4.32772155523159
#   Lowest 0-occ =  0.0132263897563843 | -0.0114703206604385 | 0.0379257463633568
#   1-occ =         -0.190047946272574 | -0.306879009350339 | -0.073216358762271
#   1-occ =         -0.044037486593998 | -0.166853035068335 | 0.0787799679658097
#   Roothaan mo_energy =
# [-4.34057347 -0.19004795  0.35991102  0.01322639  0.337776   -0.04403749
#   0.33479762  0.01322639  0.337776    0.92157301  0.92920886  0.93250684
#   0.92920886  0.92157327]
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -18.947485580164418  Ecoul = 7.1834800604681766  Exc = -2.8025977996275504
# cycle= 5 E= -14.5666033193238  delta_E= -8.5e-10  |g|= 5.8e-07  |ddm|= 0.000127
#     CPU time for cycle= 5      0.01 sec, wall time      0.01 sec
# HOMO (p+0) = -0.0440383705643485  LUMO (p+1) = 0.0132263742496924
# double occ irrep_nelec = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# single occ irrep_nelec = [1, 0, 1, 0, 0, 0, 0, 0, 0]
#                   Roothaan           | alpha              | beta
#   Highest 2-occ =  -4.34057418620433 |  -4.35342281184205 |  -4.32772556060711
#   Lowest 0-occ =  0.0132263742496924 | -0.0114715753895635 | 0.0379243238889372
#   1-occ =         -0.190048164834602 |  -0.30687807879389 | -0.0732182388775752
#   1-occ =         -0.0440383705643485 | -0.166855823630212 | 0.0787792370920568
#   Roothaan mo_energy =
# [-4.34057419 -0.19004816  0.35991115  0.01322637  0.33777589 -0.04403837
#   0.33479835  0.01322637  0.33777589  0.92157291  0.92920873  0.9325067
#   0.92920873  0.92157317]
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# E1 = -18.947487105138883  Ecoul = 7.183481993772554  Exc = -2.8025982079582934
# Extra cycle  E= -14.5666033193246  delta_E= -8.3e-13  |g|= 7.83e-08  |ddm|= 2.87e-06
#     CPU time for scf_cycle      0.13 sec, wall time      0.12 sec
#     CPU time for SCF      0.14 sec, wall time      0.13 sec
# converged SCF energy = -14.5666033193246
# -14.566603319324622

# %%
nstates = 10
sf_tda = SA_SF_TDA(mf,SA=3)

# %%
tmp_e, values = sf_tda.kernel(nstates=nstates)
print(tmp_e - tmp_e[0]) #  in eV
#sf_tda.analyse()
# Out:
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.03 sec, wall time      0.02 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# [ 0.          2.64734525  4.89562864  5.69088536  5.69088536  7.37448753
#   7.37448753  8.14057036 12.03272463 12.73569575]

# %% [markdown]
# # fglobal

# %%
foolst = np.linspace(0,1,11)

wlst = []
for foo in foolst:
    tmp_e, values = sf_tda.kernel(nstates=nstates,foo=1.0,fglobal=foo)
    w = tmp_e - tmp_e[0]
    wlst.append(w)
wlst = np.array(wlst).T
# Out:
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.03 sec, wall time      0.03 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39

# %%
import matplotlib.pyplot as plt

mk = [0,0,'.','+','x']
for i in [2,3,4]:
    plt.plot(foolst,wlst[i],marker=mk[i],ls='-')

# %%
wlst.T[0]
# Out:
# array([ 0.        ,  2.65466192,  3.7693138 ,  3.7693138 ,  5.01010049,
#         7.08080244,  7.08080244,  8.24451302, 12.10214373, 12.10214373])

# %%
foolst[5],wlst.T[5]
# Out:
# (0.5,
#  array([ 0.        ,  2.65560466,  4.7457636 ,  4.7457636 ,  4.9568202 ,
#          7.25246377,  7.25246377,  8.19689807, 12.14761484, 12.40688719]))

# %%
foolst[7],wlst.T[7]
# Out:
# (0.7000000000000001,
#  array([ 0.        ,  2.65341809,  4.93316783,  5.12788698,  5.12788698,
#          7.30702717,  7.30702717,  8.17533046, 12.11240248, 12.53526207]))

# %%
wlst.T[-1]
# Out:
# array([ 0.        ,  2.64734525,  4.89562864,  5.69088536,  5.69088536,
#         7.37448753,  7.37448753,  8.14057036, 12.03272463, 12.73569575])

# %%
import matplotlib.pyplot as plt

plt.plot(foolst,wlst[3]-wlst[2],'o-')

# %% [markdown]
# # foo

# %%
foolst = np.linspace(0,1,11)

wlst = []
for foo in foolst:
    tmp_e, values = sf_tda.kernel(nstates=nstates,foo=foo)
    w = tmp_e - tmp_e[0]
    wlst.append(w)
wlst = np.array(wlst).T
# Out:
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.03 sec, wall time      0.03 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.02 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# nelec by numeric integration = [3. 1.]
#     CPU time for vxc      0.01 sec, wall time      0.01 sec
# omega alpha hyb 0.0 0.5 0.5
# GGA
# The row of A matrix  39

# %%
import matplotlib.pyplot as plt

mk = [0,0,'.','+','x']
for i in [2,3,4]:
    plt.plot(foolst,wlst[i],marker=mk[i],ls='-')
